# %% [markdown]
# <a href="https://colab.research.google.com/github/dayanajhdz-prog/estadistica-2/blob/main/Copia_de_Problemario_Estad%C3%ADstica_Inferencial_II_Dayana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "promedio_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})
df
# Out:
#     promedio_examenes_cortos  promedio_final
# 0                         59              64
# 1                         92              84
# 2                         72              77
# 3                         90              80
# 4                         95              77
# 5                         87              81
# 6                         89              80
# 7                         77              84
# 8                         76              80
# 9                         65              69
# 10                        97              83
# 11                        42              40
# 12                        94              78
# 13                        62              65
# 14                        91              90

# %%
#1 Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
y=df["promedio_final"]
x=df["promedio_examenes_cortos"]

# %%
#2 Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="black",
    edgecolors="red",
    alpha=0.9,
    s=60,
    label="Promedio final"

)


#Titulo
plt.title(
 "Grafica de dispersion entre promedios",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Promedio examenes cortos",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Promedio final",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)     #espacio extra alrededor de los datos
plt.gca().spines[["top","right"]].set_visible(False)

#Cuadricula
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.1,      #transparencia
    color="black"
)


#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %% [markdown]
# 3¿Los datos soportan la suposición de linealidad?Sí soportan linealidad.

# %%
#4 Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y) #p es de prueba de hipotesis
                            # Ho:p=0 No hay correlacion (el cambio de una
                            #variable esta viculado con el cambio de otra)
                            #Hi:p/=0 Si hay correlacion
print(f"coeficiente correlacion (r):{r:0.4f}")
print(f"valor_p: {valor_p:0.4f}")
# Out:
# coeficiente correlacion (r):0.8646
# valor_p: 0.0000

# %% [markdown]
# El valor P es < 0.05,Ho se rechaza.Sí hay correlación.

# %%
#5 coeficiente de determinacion
print (f"coeficiente de determinacion :{r**2:0.4f}")
# Out:
# coeficiente de determinacion :0.7475

# %%
#6 Obtener la recta de regresion ajustada
import statsmodels.api as sm
x_constante =sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                       24.526822
# promedio_examenes_cortos     0.643180
# dtype: float64

# %%
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="black",
    edgecolors="red",
    alpha=0.9,
    s=30,
    label="Promedio final"

)

plt.plot(
    x,y_calculada,
    marker="o",
    color="black",
    linewidth=2.2,
    linestyle="--",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="Recta de regresion"


)



#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Promedio examenes cortos",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Promedio final",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.55)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta
# de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                                  0          1
# const                     6.441997  42.611646
# promedio_examenes_cortos  0.419219   0.867141

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión.
residuales=modelo.resid
residuales
# Out:
# 0      1.525567
# 1      0.300631
# 2      6.164228
# 3     -2.413009
# 4     -8.628908
# 5      0.516530
# 6     -1.769829
# 7      9.948329
# 8      6.591509
# 9      2.666487
# 10    -3.915268
# 11   -11.540376
# 12    -6.985729
# 13     0.596027
# 14     6.943811
# dtype: float64

# %%
#8

import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,residuales,
    marker="o",
    color="black",
    edgecolors="red",
    alpha=0.9,
    s=60,
    label="Promedio final"

)


#Titulo
plt.title(
 "Grafica de residuales",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Promedio examenes cortos",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Promedio final",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)


plt.axhline (
    y=0,  #donde esta la linea horizontal
    label="Recta de regresion", #etiqueta
    color="black",
    linestyle="--", #estilo de linea
    linewidth=1.0 #ancho de la linea

    )

# %%
#9 Test de shapiro
#Ho:hay normalidad
#Hi:no hay normalidad
#alpha=0.05

from scipy.stats import shapiro
estadistico,valor_p= shapiro(residuales)
print(f"Valor_p:{valor_p:0.4f}")
# Out:
# Valor_p:0.9018

# %% [markdown]
# El valor P es > 0.05,por lo tanto Ho es verdadera.Los datos siguen una
# distribución normal.

# %%
#10 Test de Breusch-Pagan
#Test de Brush pagan
#Ho:no hay heterocedasticidad(dispersion es igual en toda la recta)
#Hi:hay heterocedasticidad(dispersion es distinta a lo largo de la recta)
#alpha:0.05

from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2 = het_breuschpagan(residuales, x_constante)
print(f"Valor_p:{valor_p_1:0.4f}")
# Out:
# Valor_p:0.2289

# %% [markdown]
# El valor P es > 0.05,Ho es verdadera.No hay heterocedasticidad,existe
# homocedasticidad.

# %%
#11
#f(x)=24.53 + 0.6432 x
# x=promedio de examenes cortos
# x=70
#f(70)=24.53 + 0.6432(70)
#      =69.55
df.describe()
# Out:
#        promedio_examenes_cortos  promedio_final
# count                 15.000000       15.000000
# mean                  79.200000       75.466667
# std                   16.297239       12.123570
# min                   42.000000       40.000000
# 25%                   68.500000       73.000000
# 50%                   87.000000       80.000000
# 75%                   91.500000       82.000000
# max                   97.000000       90.000000

# %%
modelo.predict([1,70])
# Out:
# array([69.54941193])

# %%
modelo.predict([1,75])
# Out:
# array([72.76531124])

# %%
modelo.predict([1,84])
# Out:
# array([78.55393001])

# %%
#12 Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
# y ~ x
#Ho:beta_1 es =0 (no hay correlacion)
#Hi:beta_1 =/0 (si hay correlacion)

modelo_lineal=ols("promedio_final~promedio_examenes_cortos",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                             df       sum_sq      mean_sq          F    PR(>F)
# promedio_examenes_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual                  13.0   519.504375    39.961875        NaN       NaN

# %% [markdown]
# El valor P es < 0.05,Ho se rechaza.Sí hay relación entre las variables.

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
     "categoria_salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
     "ausencia":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]

})
df
# Out:
#     categoria_salario  ausencia
# 0                  11        18
# 1                  10        17
# 2                   8        29
# 3                   5        36
# 4                   9        11
# 5                   7        28
# 6                   3        35
# 7                  11        14
# 8                   8        20
# 9                   7        32
# 10                  2        39
# 11                  9        16
# 12                  8        31
# 13                  3        40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   categoria_salario  14 non-null     int64
#  1   ausencia           14 non-null     int64
# dtypes: int64(2)
# memory usage: 356.0 bytes

# %%
#1 Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x=df["categoria_salario"]            #variable independiete(con lo que se cuenta)
y=df["ausencia"]

# %%
#2 Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="black",
    edgecolors="blue",
    alpha=0.9,
    s=60,
    label="Ausencia"

)


#Titulo
plt.title(
 "Grafica de dispersion entre salarios y ausencias",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Categoría salario",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Ausencia",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)     #espacio extra alrededor de los datos
plt.gca().spines[["top","right"]].set_visible(False)

#Cuadricula
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.1,      #transparencia
    color="black"
)


#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %% [markdown]
# 3.¿Los datos soportan la suposición de linealidad?Sí soportan linealidad.

# %%
#4 Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y) #p es de prueba de hipotesis
                            #Ho:r=0 No hay correlacion (el cambio de una
                            #variable esta viculado con el cambio de otra
                            #Hi:r/=0 Si hay correlacion

print(f"coeficiente correlacion (r):{r:0.4f}")
print(f"valor_p: {valor_p:0.4f}")
# Out:
# coeficiente correlacion (r):-0.8801
# valor_p: 0.0000

# %% [markdown]
# El valor p es < 0.05,Ho se rechaza.Sí hay correlación.

# %%
#5 Calcule el coeficiente de determinación e interprete el resultado.
print (f"coeficiente de determinacion :{r**2:0.4f}")
# Out:
# coeficiente de determinacion :0.7746

# %%
#6 Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
#dispersión.
import statsmodels.api as sm
x_constante =sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                47.487603
# categoria_salario    -2.958678
# dtype: float64

# %%
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="black",
    edgecolors="blue",
    alpha=0.9,
    s=30,
    label="Ausencia"

)

plt.plot(
    x,y_calculada,
    marker="o",
    color="black",
    linewidth=2.2,
    linestyle="--",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="Recta de regresion"


)



#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Categoria salario",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Ausencia",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.55)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
#regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                            0          1
# const              39.707750  55.267457
# categoria_salario  -3.962455  -1.954900

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
#Parece que se verifican los supuestos?

residuales=modelo.resid
residuales
# Out:
# 0     3.057851
# 1    -0.900826
# 2     5.181818
# 3     3.305785
# 4    -9.859504
# 5     1.223140
# 6    -3.611570
# 7    -0.942149
# 8    -3.818182
# 9     5.223140
# 10   -2.570248
# 11   -4.859504
# 12    7.181818
# 13    1.388430
# dtype: float64

# %%
#8

import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,residuales,
    marker="o",
    color="black",
    edgecolors="blue",
    alpha=0.9,
    s=60,
    label="Ausencia"

)


#Titulo
plt.title(
 "Grafica de residuales",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Categoría salario",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Ausencia",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)


plt.axhline (
    y=0,  #donde esta la linea horizontal
    label="Recta de regresion", #etiqueta
    color="black",
    linestyle="--", #estilo de linea
    linewidth=1.0 #ancho de la linea

    )

# %%
#9 Realice la prueba de Shapiro para los residuales y comente el resultado.
#Ho:hay normalidad
#Hi:no hay normalidad
#alpha=0.05
from scipy.stats import shapiro
_,valor_p= shapiro (residuales)
print(f"Valor_p:{valor_p:0.4f}")
# Out:
# Valor_p:0.8933

# %% [markdown]
# El valor P es > 0.05,por lo tanto Ho se acepta.Los datos siguen una
# distribución normal.

# %%
#10 Realice la prueba de Brausch-Pagan para los residuales.

#Test de Brush pagan
#Ho:no hay heterocedasticidad(dispersion es igual en toda la recta)
#Hi:hay heterocedasticidad(dispersion es distinta a lo largo de la recta)
#alpha:0.05

from statsmodels.stats.api import het_breuschpagan
_,valor_p_bp,_,_=het_breuschpagan(residuales, x_constante)

print(f"valor_p de Breusch-Pagan:{valor_p_bp:0.4f}\n")
# Out:
# valor_p de Breusch-Pagan:0.4505

# %% [markdown]
# El valor P es > 0.05,por lo tanto Ho es verdadera.No hay heterocedasticidad, existe homocedasticidad.

# %%
#11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno.
df.describe()
# Out:
#        categoria_salario   ausencia
# count          14.000000  14.000000
# mean            7.214286  26.142857
# std             2.939874   9.882830
# min             2.000000  11.000000
# 25%             5.500000  17.250000
# 50%             8.000000  28.500000
# 75%             9.000000  34.250000
# max            11.000000  40.000000

# %%
modelo.predict([1,6])
# Out:
# array([29.73553719])

# %%
modelo.predict([1,10])
# Out:
# array([17.90082645])

# %%
modelo.predict([1,12])
# Out:
# array([11.98347107])

# %%
#12 Realice una tabla ANOVA e interprete el resultado
#Ho:beta_1 es =0 (no hay correlacion)
#Hi:beta_1 =/0 (si hay correlacion)
from statsmodels.formula.api import ols
modelo_lineal=ols("ausencia~categoria_salario",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                      df      sum_sq     mean_sq          F    PR(>F)
# categoria_salario   1.0  983.548996  983.548996  41.243954  0.000033
# Residual           12.0  286.165289   23.847107        NaN       NaN

# %% [markdown]
# Como P es < 0.05 se rechaza Ho.Sí hay relación lineal entre las categorías.

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
     "gasto_general":[191,170,272,155,280,173,234,116,153,178],
     "unidades":[40,42,53,35,56,39,48,30,37,40]

})
df
# Out:
#    gasto_general  unidades
# 0            191        40
# 1            170        42
# 2            272        53
# 3            155        35
# 4            280        56
# 5            173        39
# 6            234        48
# 7            116        30
# 8            153        37
# 9            178        40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gasto_general  10 non-null     int64
#  1   unidades       10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#        gasto_general   unidades
# count      10.000000  10.000000
# mean      192.200000  42.000000
# std        53.349581   8.082904
# min       116.000000  30.000000
# 25%       158.750000  37.500000
# 50%       175.500000  40.000000
# 75%       223.250000  46.500000
# max       280.000000  56.000000

# %%
#1 Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x=df["unidades"]            #variable independiete(con lo que se cuenta)
y=df["gasto_general"]     #variable de interes (variable dependiente)

# %%
#2 Grafico de dispersion
import matplotlib.pyplot as plt

#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="black",
    edgecolors="orange",
    alpha=0.9,
    s=60,
    label="Gastos generales"

)


#Titulo
plt.title(
 "Grafica de dispersion entre unidades y gastos generales",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Unidades producidas",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Gastos generales",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)     #espacio extra alrededor de los datos
plt.gca().spines[["top","right"]].set_visible(False)

#Cuadricula
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.1,      #transparencia
    color="black"
)


#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %% [markdown]
# 3.¿Los datos soportan la suposición de linealidad? Sí.

# %%
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y) #p es de prueba de hipotesis
                            #Ho:r=0 No hay correlacion (el cambio de una variable esta viculado con el cambio de otra variable)
                            #Hi:r/=0 Si hay correlacion

print(f"coeficiente correlacion (r):{r:0.4f}")
print(f"valor_p: {valor_p:0.4f}")
# Out:
# coeficiente correlacion (r):0.9835
# valor_p: 0.0000

# %% [markdown]
# Sí hay correlacion

# %%
#5 Calcule el coeficiente de determinación e interprete el resultado.
print (f"coeficiente de determinacion :{r**2:0.4f}")
# Out:
# coeficiente de determinacion :0.9673

# %%
#6 Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
#dispersión.

import statsmodels.api as sm
x_constante =sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const      -80.442857
# unidades     6.491497
# dtype: float64

# %%
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="black",
    edgecolors="orange",
    alpha=0.9,
    s=30,
    label="Gastos generales"

)

plt.plot(
    x,y_calculada,
    marker="o",
    color="black",
    linewidth=2.2,
    linestyle="--",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="Recta de regresion"


)



#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Construcion de casas",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Ventas de linea blanca",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.55)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente
#de la recta de regresion ajustada

modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# unidades    5.518450   7.464543

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
#Parece que se verifican los supuestos?

residuales=modelo.resid
residuales
# Out:
# 0    11.782993
# 1   -22.200000
# 2     8.393537
# 3     8.240476
# 4    -3.080952
# 5     0.274490
# 6     2.851020
# 7     1.697959
# 8    -6.742517
# 9    -1.217007
# dtype: float64

# %%
#8

import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,residuales,
    marker="o",
    color="black",
    edgecolors="orange",
    alpha=0.9,
    s=60,
    label="Gastos generales (residuales)"

)


#Titulo
plt.title(
 "Grafica de residuales",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Construcion de casas",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Ventas de linea blanca",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)


plt.axhline (
    y=0,  #donde esta la linea horizontal
    label="Recta de regresion", #etiqueta
    color="black",
    linestyle="--", #estilo de linea
    linewidth=1.0 #ancho de la linea

    )

# %%
#9 Realice la prueba de Shapiro para los residuales y comente el resultado.
#Ho:hay normalidad
#Hi:no hay normalidad
#alpha=0.05
from scipy.stats import shapiro
_,valor_p= shapiro (residuales)
print(f"Valor_p:{valor_p:0.4f}")
# Out:
# Valor_p:0.2205

# %% [markdown]
# Como el valor P es mayor al nivel de significancia, Ho es verdadero, los datos siguen una distribucion normal.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

#Prueba de shapiro
stat, valor_p=shapiro(residuales)
print(f"Valor_p:{valor_p:0.4f}")

#Visualizacion
sm.qqplot(residuales,line="s")
plt.show()

#Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuales")
plt.show()
# Out:
# Valor_p:0.2205

# %%
#10 Realice la prueba de Brausch-Pagan para los residuales y comente el
#resultado.

#Test de Brush pagan
#Ho:no hay heterocedasticidad(dispersion es igual en toda la recta)
#Hi:hay heterocedasticidad(dispersion es distinta a lo largo de la recta)
#alpha:0.05

from statsmodels.stats.api import het_breuschpagan
_,valor_p_bp,_,_=het_breuschpagan(residuales, x_constante)

print(f"valor_p de Breusch-Pagan:{valor_p_bp:0.4f}\n")
# Out:
# valor_p de Breusch-Pagan:0.9858

# %% [markdown]
# El valor P es mayor,Ho es verdadero,no hay heterocedasticidad,hay
# homocedasticidad.

# %%
#11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno
df.describe()
# Out:
#        gasto_general   unidades
# count      10.000000  10.000000
# mean      192.200000  42.000000
# std        53.349581   8.082904
# min       116.000000  30.000000
# 25%       158.750000  37.500000
# 50%       175.500000  40.000000
# 75%       223.250000  46.500000
# max       280.000000  56.000000

# %%
modelo.predict([1,40])
# Out:
# array([179.2170068])

# %%
modelo.predict([1,50])
# Out:
# array([244.13197279])

# %%
modelo.predict([1,80])
# Out:
# array([438.87687075])

# %%
#12 Anova
#Ho:beta_1 es =0 (no hay correlacion)
#Hi:beta_1 =/0 (si hay correlacion)
from statsmodels.formula.api import ols
modelo_lineal=ols("gasto_general~unidades",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#            df        sum_sq       mean_sq           F        PR(>F)
# unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# Como P < al nivel de significancia Ho se rechaza.
# Sí hay relación lineal entre variables.

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "construccion_de_casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
    "ventas_de_linea_blanca":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]
})
df
# Out:
#    construccion_de_casas  ventas_de_linea_blanca
# 0                    2.0                     5.0
# 1                    2.5                     5.5
# 2                    3.2                     6.0
# 3                    3.6                     7.0
# 4                    3.7                     7.2
# 5                    4.0                     7.7
# 6                    4.2                     8.4
# 7                    4.6                     9.0
# 8                    4.8                     9.7
# 9                    5.0                    10.0

# %%
#1 Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x=df["construccion_de_casas"]
y=df["ventas_de_linea_blanca"]

# %%
#2 Grafico de dispersion
import matplotlib.pyplot as plt

#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="black",
    edgecolors="purple",
    alpha=0.9,
    s=60,
    label="Ventas de linea blanca"

)


#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Construccion de casas",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Ventas de linea blanca",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)     #espacio extra alrededor de los datos
plt.gca().spines[["top","right"]].set_visible(False)

#Cuadricula
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.1,      #transparencia
    color="black"
)


#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %% [markdown]
# 3.¿Los datos soportan la suposición de linealidad? Si soportan suposicion de linealidad

# %%
#4 Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y) #p es de prueba de hipotesis
                            #Ho:p=0 No hay correlacion(el cambio de una variable
                            #esta viculado con el cambio de otra variable)
                            #Hi:p/=0 Si hay correlacion

print(f"coeficiente correlacion (r):{r:0.4f}")
print(f"valor_p: {valor_p:0.4f}")
# Out:
# coeficiente correlacion (r):0.9808
# valor_p: 0.0000

# %% [markdown]
# Valor P es menor a cualquier nivel de significancia,por lo tanto Ho es falso.Sí hay correlacion

# %%
#5 Calcule el coeficiente de determinación e interprete el resultado.
print (f"coeficiente de determinacion :{r**2:0.4f}")
# Out:
# coeficiente de determinacion :0.9619

# %%
#6 Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante =sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                    1.016760
# construccion_de_casas    1.737564
# dtype: float64

# %%
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="black",
    edgecolors="#f527E4",
    alpha=0.9,
    s=60,
    label="Ventas de linea blanca"

)

plt.plot(
    x,y_calculada,
    marker="o",
    color="black",
    linewidth=2.2,
    linestyle="--",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="Recta de regresion"


)



#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Construcion de casas",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Ventas de linea blanca",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.55)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                               0         1
# const                 -0.074848  2.108368
# construccion_de_casas  1.455693  2.019435

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
#Parece que se verifican los supuestos?

residuales=modelo.resid
residuales
# Out:
# 0    0.508113
# 1    0.139331
# 2   -0.576964
# 3   -0.271990
# 4   -0.245746
# 5   -0.267015
# 6    0.085472
# 7   -0.009554
# 8    0.342934
# 9    0.295421
# dtype: float64

# %%
#8
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,residuales,
    marker="o",
    color="black",
    edgecolors="#f527E4",
    alpha=0.9,
    s=60,
    label="Ventas de linea blanca"

)



#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Construcion de casas",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Ventas de linea blanca",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)


plt.axhline (
    y=0,  #donde esta la linea horizontal
    label="Recta de regresion", #etiqueta
    color="black",
    linestyle="--", #estilo de linea
    linewidth=1.0 #ancho de la linea


)

# %%
#9 Prueba de  Shapiro para los residuales y comente el resultado.
#Ho:hay normalidad
#Hi:no hay normalidad
#alpha=0.05
from scipy.stats import shapiro
_,valor_p= shapiro (residuales)
print(f"Valor_p:{valor_p:0.4f}")
# Out:
# Valor_p:0.8464

# %% [markdown]
# El valor P es >0.05,por lo tanto Ho es verdadero.Los datos siguen una distribución normal.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

#Prueba de shapiro
stat, valor_p=shapiro(residuales)
print(f"Valor_p:{valor_p:0.4f}")

#Visualizacion
sm.qqplot(residuales,line="s")
plt.show()

#Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuales")
plt.show()
# Out:
# Valor_p:0.8464

# %%
#10  Realice la prueba de Brausch-Pagan para los residuales y comente el
#resultado.

#Test de Brush pagan
#Ho:no hay heterocedasticidad(dispersion es igual en toda la recta)
#Hi:hay heterocedasticidad(dispersion es distinta a lo largo de la recta)
#alpha:0.05

from statsmodels.stats.api import het_breuschpagan
_,valor_p_bp,_,_=het_breuschpagan(residuales, x_constante)
print(f"valor_p de Breusch-Pagan:{valor_p_bp:0.4f}\n")
# Out:
# valor_p de Breusch-Pagan:0.1581

# %% [markdown]
# El valor P es > 0.05,por lo tanto Ho es verdadera.No hay heterocedasticidad,existe homocedasticidad.

# %%
#11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno.
df.describe()
# Out:
#        construccion_de_casas  ventas_de_linea_blanca
# count              10.000000               10.000000
# mean                3.760000                7.550000
# std                 0.977753                1.732211
# min                 2.000000                5.000000
# 25%                 3.300000                6.250000
# 50%                 3.850000                7.450000
# 75%                 4.500000                8.850000
# max                 5.000000               10.000000

# %%
modelo.predict([1,3])
# Out:
# array([6.22945142])

# %%
modelo.predict([1,4])
# Out:
# array([7.96701534])

# %%
modelo.predict([1,7])
# Out:
# array([13.17970711])

# %%
#12 Realice una tabla ANOVA e interprete el resultado.
#Ho:beta_1 es =0 (no hay correlacion)
#Hi:beta_1 =/0 (si hay correlacion)
from statsmodels.formula.api import ols
modelo_lineal=ols("ventas_de_linea_blanca~construccion_de_casas",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df     sum_sq    mean_sq           F        PR(>F)
# construccion_de_casas  1.0  25.976581  25.976581  202.069951  5.841003e-07
# Residual               8.0   1.028419   0.128552         NaN           NaN

# %% [markdown]
# El valor P es < 0.05,Ho se rechaza.Sí hay relación lineal entre las variables.

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "numero_interrupcion_trabajador":[5,10,10,15,15,20,20,25],
    "calificacion_trabajador":[58,41,45,27,26,12,16,3]
})
df
# Out:
#    numero_interrupcion_trabajador  calificacion_trabajador
# 0                               5                       58
# 1                              10                       41
# 2                              10                       45
# 3                              15                       27
# 4                              15                       26
# 5                              20                       12
# 6                              20                       16
# 7                              25                        3

# %%
#1 Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x=df["numero_interrupcion_trabajador"]
y=df["calificacion_trabajador"]

# %%
#2 Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="pink",
    edgecolors="black",
    alpha=0.9,
    s=60,
    label="Calificación del trabajador en prueba de hostilidad"

)


#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Numero interrupciones al trabajador",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Calificacion del trabajador en prueba de hostilidad",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)     #espacio extra alrededor de los datos
plt.gca().spines[["top","right"]].set_visible(False)

#Cuadricula
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.1,      #transparencia
    color="black"
)


#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %% [markdown]
# 3. Los datos soportan la suposición de linealidad?Sí

# %%
#4 Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y) #p es de prueba de hipotesis
                            #Ho:p=0 No hay correlacion(el cambio de una variable
                            #esta viculado con el cambio de otra variable)
                            #Hi:p/=0 Si hay correlacion

print(f"coeficiente correlacion (r):{r:0.4f}")
print(f"valor_p: {valor_p:0.4f}")
# Out:
# coeficiente correlacion (r):-0.9928
# valor_p: 0.0000

# %% [markdown]
# El valor P es < 0.05, se rechaza Ho. Sí hay correlación

# %%
#5 Calcule el coeficiente de determinación e interprete el resultado.
print (f"coeficiente de determinacion :{r**2:0.4f}")
# Out:
# coeficiente de determinacion :0.9858

# %%
#6 import statsmodels.api as sm
x_constante =sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                             70.5
# numero_interrupcion_trabajador    -2.8
# dtype: float64

# %%
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="pink",
    edgecolors="black",
    alpha=0.9,
    s=60,
    label="Calificacion del trabajador en prueba de hostilidad"

)

plt.plot(
    x,y_calculada,
    marker="o",
    color="black",
    linewidth=2.2,
    linestyle="--",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="Recta de regresion"


)



#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Numero interrupciones al trabajador",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Calificacion del trabajador en prueba de hostilidad",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.55)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
#regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                                         0          1
# const                           65.051384  75.948616
# numero_interrupcion_trabajador  -3.136296  -2.463704

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
#Parece que se verifican los supuestos?

residuales=modelo.resid
residuales
# Out:
# 0    1.5
# 1   -1.5
# 2    2.5
# 3   -1.5
# 4   -2.5
# 5   -2.5
# 6    1.5
# 7    2.5
# dtype: float64

# %%
#8
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,residuales,
    marker="o",
    color="pink",
    edgecolors="black",
    alpha=0.9,
    s=60,
    label="Calificacion del trabajador en prueba de hostilidad"

)



#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Numero interrupciones al trabajador",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Calificacion del trabajador en prueba de hostilidad",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)


plt.axhline (
    y=0,  #donde esta la linea horizontal
    label="Recta de regresion", #etiqueta
    color="black",
    linestyle="--", #estilo de linea
    linewidth=1.0 #ancho de la linea


)

# %%
#9 Realice la prueba de Shapiro para los residuales y comente el resultado.
#Ho:hay normalidad
#Hi:no hay normalidad
#alpha=0.05
from scipy.stats import shapiro
_,valor_p= shapiro (residuales)
print(f"Valor_p:{valor_p:0.4f}")
# Out:
# Valor_p:0.0548

# %% [markdown]
# El valor P es > 0.05, por lo tanto Ho es verdadero.Los datos siguen una distribución normal.

# %%
#10 Realice la prueba de Brausch-Pagan para los residuales y comente el
#resultado.

#Test de Brush pagan
#Ho:no hay heterocedasticidad(dispersion es igual en toda la recta)
#Hi:hay heterocedasticidad(dispersion es distinta a lo largo de la recta)
#alpha:0.05

from statsmodels.stats.api import het_breuschpagan
_,valor_p_bp,_,_=het_breuschpagan(residuales, x_constante)
print(f"valor_p de Breusch-Pagan:{valor_p_bp:0.4f}\n")
# Out:
# valor_p de Breusch-Pagan:0.2482

# %% [markdown]
# El valor P es > 0.05,por lo tanto Ho es verdadero. Existe homocedasticidad.

# %%
#11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno
df.describe()
# Out:
#        numero_interrupcion_trabajador  calificacion_trabajador
# count                        8.000000                 8.000000
# mean                        15.000000                28.500000
# std                          6.546537                18.462317
# min                          5.000000                 3.000000
# 25%                         10.000000                15.000000
# 50%                         15.000000                26.500000
# 75%                         20.000000                42.000000
# max                         25.000000                58.000000

# %%
modelo.predict([1,13])
# Out:
# array([34.1])

# %%
modelo.predict([1,20])
# Out:
# array([14.5])

# %%
modelo.predict([1,35])
# Out:
# array([-27.5])

# %%
#12 Realice una tabla ANOVA e interprete el resultado.
#Ho:beta_1 es =0 (no hay correlacion)
#Hi:beta_1 =/0 (si hay correlacion)
from statsmodels.formula.api import ols
modelo_lineal=ols("calificacion_trabajador~numero_interrupcion_trabajador",
data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                  df  sum_sq      mean_sq           F  \
# numero_interrupcion_trabajador  1.0  2352.0  2352.000000  415.058824
# Residual                        6.0    34.0     5.666667         NaN
#
#                                       PR(>F)
# numero_interrupcion_trabajador  9.090964e-07
# Residual                                 NaN

# %% [markdown]
# El valor p es < 0.05. Sí hay relación lineal entre las variables.
