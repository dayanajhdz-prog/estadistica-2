# %% [markdown]
# <a href="https://colab.research.google.com/github/dayanajhdz-prog/estadistica-2/blob/main/Copia_de_Examen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pad
link="https://raw.githubusercontent.com/dayanajhdz-prog/estadistica-2/refs/heads/main/gym_members.csv/gym_members.csv"
df=pad.read_csv(link)
df
# Out:
#      Edad  Genero  peso (kg)  Estatura (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0      56    Male       88.3          1.71      180      157           60
# 1      46  Female       74.9          1.53      179      151           66
# 2      32  Female       68.1          1.66      167      122           54
# 3      25    Male       53.2          1.70      190      164           56
# 4      38    Male       46.1          1.79      188      158           68
# ..    ...     ...        ...           ...      ...      ...          ...
# 968    24    Male       87.1          1.74      187      158           67
# 969    25    Male       66.6          1.61      184      166           56
# 970    59  Female       60.4          1.76      194      120           53
# 971    32    Male      126.4          1.83      198      146           62
# 972    46    Male       88.7          1.63      166      146           66
#
#      Duracion_sesion(hours)  Calories_quemadas Tipo_entrenamiento  \
# 0                      1.69             1313.0               Yoga
# 1                      1.30              883.0               HIIT
# 2                      1.11              677.0             Cardio
# 3                      0.59              532.0           Strength
# 4                      0.64              556.0           Strength
# ..                      ...                ...                ...
# 968                    1.57             1364.0           Strength
# 969                    1.38             1260.0           Strength
# 970                    1.72              929.0             Cardio
# 971                    1.10              883.0               HIIT
# 972                    0.75              542.0           Strength
#
#      Porcentaje_grasa_corporal  Consumo_de_agua (liters)  \
# 0                         12.6                       3.5
# 1                         33.9                       2.1
# 2                         33.4                       2.3
# 3                         28.8                       2.1
# 4                         29.2                       2.8
# ..                         ...                       ...
# 968                       10.0                       3.5
# 969                       25.0                       3.0
# 970                       18.8                       2.7
# 971                       28.2                       2.1
# 972                       28.8                       3.5
#
#      Frequencia_entrenamiento (days/week)  Nivel_experiencia    IMC
# 0                                       4                  3  30.20
# 1                                       4                  2  32.00
# 2                                       4                  2  24.71
# 3                                       3                  1  18.41
# 4                                       3                  1  14.39
# ..                                    ...                ...    ...
# 968                                     4                  3  28.77
# 969                                     2                  1  25.69
# 970                                     5                  3  19.50
# 971                                     3                  2  37.74
# 972                                     2                  1  33.38
#
# [973 rows x 15 columns]

# %%
#1 Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
y=df["Calories_quemadas"]
x=df["Duracion_sesion(hours)"]

# %%
#2 Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="black",
    edgecolors="red",
    alpha=0.9,
    s=60,
    label="Calorias quemadas"

)


#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Duracion_sesion(hours)",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Calories_quemadas",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)     #espacio extra alrededor de los datos
plt.gca().spines[["top","right"]].set_visible(False)

#Cuadricula
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.1,      #transparencia
    color="black"
)


#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#3¿Los datos soportan la suposición de linealidad?Sí soporta linealidad

# %%
#4 Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y) #p es de prueba de hipotesis
                            # Ho:p=0 No hay correlacion (el cambio de una variable esta viculado con el cambio de otra variable)
                            #Hi:p/=0 Si hay correlacion
print(f"coeficiente correlacion (r):{r:0.4f}")
print(f"valor_p: {valor_p:0.4f}")
# Out:
# coeficiente correlacion (r):0.9081
# valor_p: 0.0000

# %% [markdown]
# El valor P es < 0.05, se rechaza Ho.Sí hay correlación.

# %%
#5 coeficiente de determinacion
print (f"coeficiente de determinacion :{r**2:0.4f}")
# Out:
# coeficiente de determinacion :0.8247

# %%
#6 Obtener la recta de regresion ajustada
import statsmodels.api as sm
x_constante =sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                      -1.446459
# Duracion_sesion(hours)    721.786016
# dtype: float64

# %%
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,y,
    marker="o",
    color="black",
    edgecolors="red",
    alpha=0.9,
    s=30,
    label="Calorias quemadas"

)

plt.plot(
    x,y_calculada,
    marker="o",
    color="black",
    linewidth=2.2,
    linestyle="--",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="Recta de regresion"


)



#Titulo
plt.title(
 "Grafica de dispersion",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Duracions sesion(hours)",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Calorias quemadas",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.55)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta
# de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                                  0           1
# const                   -28.738459   25.845542
# Duracion_sesion(hours)  700.830270  742.741762

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión.
residuales=modelo.resid
residuales
# Out:
# 0       94.628092
# 1      -53.875362
# 2     -122.736019
# 3      107.592709
# 4       95.503409
#           ...
# 968    232.242414
# 969    265.381757
# 970   -311.025489
# 971     90.481841
# 972      2.106947
# Length: 973, dtype: float64

# %%
#8

import matplotlib.pyplot as plt
#configuracion general
plt.figure(
figsize=(6,4),
  dpi=100
)


#grafico de dispersion
plt.scatter(
    x,residuales,
    marker="o",
    color="black",
    edgecolors="red",
    alpha=0.9,
    s=60,
    label="Calorias quemadas"

)


#Titulo
plt.title(
 "Grafica de residuales",
 fontsize=12,
 fontweight="bold"


)
#Etiqueta eje x
plt.xlabel (
    "Duracions sesion(hours)",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel (
    "Calorias quemadas",
    fontsize=10

)

#tamaño de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

#malla
plt.grid(
    visible= True,
    linestyle="--",
    linewidth= 0.7, #ancho de linea
    alpha=0.5,      #transparencia
    color="black"
)

#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon= False
    #bbox_to_anchor=(0.5,-0.15)

)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)


plt.axhline (
    y=0,  #donde esta la linea horizontal
    label="Recta de regresion", #etiqueta
    color="black",
    linestyle="--", #estilo de linea
    linewidth=1.0 #ancho de la linea

    )

# %%
#9 Test de shapiro
#Ho:hay normalidad
#Hi:no hay normalidad
#alpha=0.05

from scipy.stats import shapiro
estadistico,valor_p= shapiro(residuales)
print(f"Valor_p:{valor_p:0.4f}")
# Out:
# Valor_p:0.0038

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

#Prueba de shapiro
stat, valor_p=shapiro(residuales)
print(f"Valor_p:{valor_p:0.4f}")

#Visualizacion
sm.qqplot(residuales,line="s")
plt.show()

#Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuales")
plt.show()
# Out:
# Valor_p:0.0038
